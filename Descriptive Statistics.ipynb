# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/inetpub/New excel/Employee Dataset.csv")

# %%
df.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (50, 6)

# %%
df.describe()
# Out:
#              id        age  healthy_eating  active_lifestyle       salary
# count  50.00000  50.000000       50.000000         50.000000    50.000000
# mean   24.50000  31.880000        4.920000          5.900000  2027.500000
# std    14.57738   8.390082        1.827678          2.022829  1076.861885
# min     0.00000  22.000000        1.000000          1.000000   556.000000
# 25%    12.25000  26.250000        3.250000          5.000000  1134.000000
# 50%    24.50000  30.000000        5.000000          6.000000  1950.000000
# 75%    36.75000  35.750000        6.000000          7.000000  2732.250000
# max    49.00000  62.000000        9.000000         10.000000  4969.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data= df, x='age',y ='salary', color='blue',
               edgecolor = 'linen', alpha=0.5)
plt.title('Scatterplot of Employee age v/s Employee salary')
plt.xlabel('Employee age')
plt.ylabel('Employee salary')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data= df, x='healthy_eating',y ='active_lifestyle', color='red',
               edgecolor = 'linen', alpha=0.5)
plt.title('Scatterplot of Healthy eating v/s Active lifestyle')
plt.xlabel('Healthy eating')
plt.ylabel('Active lifestyle')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data= df, x='healthy_eating',y ='salary', color='purple',
               edgecolor = 'linen', alpha=0.5)
plt.title('Scatterplot of Healthy eating v/s salary')
plt.xlabel('Healthy eating')
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data= df, x='groups',
               edgecolor = 'linen', alpha=0.7)
plt.title('Countplot of groups')
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data= df, x='salary', color='orange',
               edgecolor = 'linen', alpha=0.7,bins=10)
plt.title('Histogram of salary')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %%
# employee healthy eating greater than 8
sub1 = df[df['healthy_eating']>8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
# salary less than 1000
sub2  = df[df['salary']<1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
sub = df[(df['healthy_eating']>8) & (df['salary']<1000)]
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700
